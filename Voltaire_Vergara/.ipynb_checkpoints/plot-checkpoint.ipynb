# %% [markdown]
# # Block Groups in Buffalo that are prone to Gentrification
#
# below are all the shape files of every block in Erie county

# %%
# %matplotlib inline

import pandas as pd
import geopandas
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
#import pysal.esda.mapclassify as ps
#from pysal.esda.mapclassify import User_Defined


block_grp = geopandas.read_file("2018NYblockgrpSF/tl_2018_36_bg.shp")
block_grp = block_grp.rename(columns={'TRACTCE': 'Tract', 'BLKGRPCE': 'Block'})
erie_county_blockGrp = block_grp[(block_grp.COUNTYFP == "029")]
erie_county_blockGrp.head()
# Out:
#    STATEFP COUNTYFP   Tract Block         GEOID       NAMELSAD  MTFCC  \
# 11      36      029  014603     2  360290146032  Block Group 2  G5030
# 12      36      029  014601     2  360290146012  Block Group 2  G5030
# 13      36      029  014601     4  360290146014  Block Group 4  G5030
# 14      36      029  014601     3  360290146013  Block Group 3  G5030
# 15      36      029  014603     3  360290146033  Block Group 3  G5030
#
#    FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 11        S  1992416       0  +42.9837512  -078.6869747
# 12        S  2237921       0  +42.9608352  -078.6827714
# 13        S  2362636       0  +42.9716503  -078.6869950
# 14        S  1790691       0  +42.9714220  -078.6691991
# 15        S  2185747       0  +42.9806768  -078.6542591
#
#                                              geometry
# 11  POLYGON ((-78.69695 42.98929, -78.69562 42.989...
# 12  POLYGON ((-78.69695 42.95930, -78.69688 42.962...
# 13  POLYGON ((-78.69693 42.97632, -78.69687 42.976...
# 14  POLYGON ((-78.67719 42.96713, -78.67717 42.968...
# 15  POLYGON ((-78.66214 42.97657, -78.66212 42.977...

# %%
erie_county_blockGrp.plot() #THIS IS ERIE COUNTY PICTURE

# %% [markdown]
# ## Gentrification Blocks
# Below are the blocks that are indicated on the reading that are going through the process of gentrification.
#
# #### Lower West Side Neighborhood
#     eight census block groups located in parts of three census tracts (69.02 BG2, 69.02 BG4, 71.01 BG1, 71.02 BG2, 71.01 BG3, 71.01 BG4, 71.02 BG2, and 71.02 BG3).
# #### Elicott Neighborhoood
#     three census block group located in one census tract. (14.02 BG1, 14.02 BG2 and 14.02 BG4).
#    <img src="images/Elicott.JPG">
#
# #### Fruit Belt Neighborhood
#     The Fruit Belt neighborhood is composed of four census block groups located in one census tract (31 BG1, 31 BG2, 31 BG3 and 31 BG4).

# %%
elicott = erie_county_blockGrp#[(erie_county_blockGrp.Tract == "001402") & (erie_county_blockGrp.Block != "3")]
elicott.head()
# Out:
#    STATEFP COUNTYFP   Tract Block         GEOID       NAMELSAD  MTFCC  \
# 11      36      029  014603     2  360290146032  Block Group 2  G5030
# 12      36      029  014601     2  360290146012  Block Group 2  G5030
# 13      36      029  014601     4  360290146014  Block Group 4  G5030
# 14      36      029  014601     3  360290146013  Block Group 3  G5030
# 15      36      029  014603     3  360290146033  Block Group 3  G5030
#
#    FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 11        S  1992416       0  +42.9837512  -078.6869747
# 12        S  2237921       0  +42.9608352  -078.6827714
# 13        S  2362636       0  +42.9716503  -078.6869950
# 14        S  1790691       0  +42.9714220  -078.6691991
# 15        S  2185747       0  +42.9806768  -078.6542591
#
#                                              geometry
# 11  POLYGON ((-78.69695 42.98929, -78.69562 42.989...
# 12  POLYGON ((-78.69695 42.95930, -78.69688 42.962...
# 13  POLYGON ((-78.69693 42.97632, -78.69687 42.976...
# 14  POLYGON ((-78.67719 42.96713, -78.67717 42.968...
# 15  POLYGON ((-78.66214 42.97657, -78.66212 42.977...

# %%
elicott_data = geopandas.read_file("Gentrification_data/erie_county-2013.csv")
del elicott_data['geometry']
elicott_data.rename(columns = {'tract':'Tract', 'block group': 'Block'})
elicott_data.replace(to_replace=['None'], value=np.nan, inplace=True)
elicott_data_to_float = elicott_data.astype(float)
elicott_data_to_float.fillna(elicott_data_to_float.mean(), inplace = True)
#elicott_data_to_float['Block'] = elicott_data['Block']
#elicott_data_to_float['Tract'] = elicott_data['Tract']

elicott_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Block'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-c6cab0c798f4> in <module>
#       5 elicott_data_to_float = elicott_data.astype(float)
#       6 elicott_data_to_float.fillna(elicott_data_to_float.mean(), inplace = True)
# ----> 7 elicott_data_to_float['Block'] = elicott_data['Block']
#       8 elicott_data_to_float['Tract'] = elicott_data['Tract']
#       9
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     544         GeoDataFrame.
#     545         """
# --> 546         result = super(GeoDataFrame, self).__getitem__(key)
#     547         geo_col = self._geometry_column_name
#     548         if isinstance(key, string_types) and key == geo_col:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Block'

# %%
elicott = elicott.merge(elicott_data_to_float,on = ['Tract','Block'])
# =================== These are appended onto the data frame to have the bins treshold limit from 0 to 100 ========
elicott.loc[3] = 0
elicott.loc[4] = 20
elicott.loc[5] = 40
elicott.loc[6] = 60
elicott.loc[7] = 80
elicott.loc[8] = 100
# ==================================================================================================================
titles = elicott.filter(like = 'Percent').columns
fig, ax = plt.subplots(figsize=(8,8))
ax.set_axis_off()
ax.set_title(titles[1] +  " 2016", fontsize = 10)
#ud = User_Defined(elicott[titles[1]], bins)

#plot_dataframe(s = elicott, column = titles[6], fig = fig, ax = ax, binning = ud, cmap = 'Reds')

elicott.plot(column = titles[1], ax = ax, legend = True
            , cmap='OrRd', scheme = 'equalinterval', edgecolor = "black")
#fig.savefig('images/' + titles[1] + ' 2016.png')
len(titles)
# Out:
# 9

# %% [markdown]
# ### Each map plotted will be placed onto the images folder

# %%
for title in titles: 
    #print(title)
    ax.set_title(title +  " 2016", fontsize = 10)
    elicott.plot(column = title, ax = ax, legend = True, cmap='OrRd', scheme = 'equal_interval'
            , edgecolor = "black")
    fig.savefig('images/percent/' + title + ' 2016.png')

# %%
titles = elicott.filter(like = 'Total').columns
elicott.drop(elicott.index[[3,4,5,6,7,8]], inplace = True)
for title in titles: 
    #print(title)
    ax.set_title(title +  " 2016", fontsize = 10)
    elicott.plot(column = title, ax = ax, legend = True, cmap='OrRd', scheme = 'equal_interval'
            , edgecolor = "black")
    fig.savefig('images/total/' + title + ' 2016.png')
elicott
# Out:
#   STATEFP COUNTYFP   Tract Block         GEOID       NAMELSAD  MTFCC FUNCSTAT  \
# 0      36      029  001402     4  360290014024  Block Group 4  G5030        S
# 1      36      029  001402     2  360290014022  Block Group 2  G5030        S
# 2      36      029  001402     1  360290014021  Block Group 1  G5030        S
#
#     ALAND  AWATER  ... Percent Number of Vacant Housing Units  \
# 0  403167       0  ...                                  31.13
# 1  150487       0  ...                                  36.97
# 2  157335       0  ...                                   9.48
#
#   Total Population for whom poverty status is determined  \
# 0                                              418.0
# 1                                              387.0
# 2                                              839.0
#
#   Total below povery line (population whose poverty level is determined)  \
# 0                                               77.0
# 1                                              196.0
# 2                                              333.0
#
#    Percent below povery line (population whose poverty level is determined)  \
# 0                                              18.42
# 1                                              50.65
# 2                                              39.69
#
#    Total Median Gross Rent As A Percentage Of Household Income In The Past 12 Months (Dollars)  \
# 0                                               13.3
# 1                                               31.6
# 2                                               31.4
#
#    Total Population that is 25 years and older  \
# 0                                        362.0
# 1                                        226.0
# 2                                        602.0
#
#    Total Population 25 years and older that have less than a college education  \
# 0                                              227.0
# 1                                              135.0
# 2                                              394.0
#
#    Percent Population 25 years and older that have less than a college education  \
# 0                                              62.71
# 1                                              59.73
# 2                                              65.45
#
#    Total Median contract rent (DOLLARS)  Total Median Housing values (DOLLARS)
# 0                                 381.0                               108700.0
# 1                                 232.0                           -666666666.0
# 2                                 349.0                                85800.0
#
# [3 rows x 37 columns]
